# %% [markdown]
# # Breast Cancer Wisconsin (Diagnostic) Data Set

# %%
# Import Libraries
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# Configuring styles
sns.set_style("darkgrid")
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (16, 9)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## Dataset

# %%
data_df = pd.read_csv('./data.csv')
data_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data_df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
data_df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data_df.sample(10)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 48      857155         B       12.050         14.63           78.04
# 397   90401602         B       12.800         17.46           83.05
# 368    9011971         M       21.710         17.25          140.90
# 463  911320501         B       11.600         18.36           73.88
# 501      91504         M       13.820         24.49           92.33
# 470    9113778         B        9.667         18.49           61.49
# 411     905520         B       11.040         16.83           70.92
# 533   91930402         M       20.470         20.67          134.70
# 57      857793         M       14.710         21.59           95.55
# 97      862261         B        9.787         19.94           62.11
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 48       449.3          0.10310           0.09092        0.065920
# 397      508.3          0.08044           0.08895        0.073900
# ...

# %% [markdown]
# ## Remove null column and not related column

# %%
data_df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Deleting the id and Unnamed column
data_df= data_df.drop(['Unnamed: 32','id'],axis=1)

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(data_df,
             hue = 'diagnosis',
             x_vars = ['radius_mean', 
                       'texture_mean', 
                       'perimeter_mean',
                       'area_mean', 
                       'smoothness_mean'],
             y_vars = ['radius_mean', 
                       'texture_mean', 
                       'perimeter_mean',
                       'area_mean', 
                       'smoothness_mean'])
# Out:
# C:\Users\yuyla\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Convert diagnosis to Boolean value

# %%
data2_df = data_df.copy()
data2_df.diagnosis.replace({'M': True, 'B': False}, inplace=True)
data2_df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         True        17.99         10.38          122.80     1001.0
# 1         True        20.57         17.77          132.90     1326.0
# 2         True        19.69         21.25          130.00     1203.0
# 3         True        11.42         20.38           77.58      386.1
# 4         True        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564       True        21.56         22.39          142.00     1479.0
# 565       True        20.13         28.25          131.20     1261.0
# 566       True        16.60         28.08          108.30      858.1
# 567       True        20.60         29.33          140.10     1265.0
# 568      False         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ## Correlation

# %%
data3_df = data_df.iloc[:,1:]
data3_df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
corr = data3_df.corr()
corr
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.figsize'] = (18, 9)
sns.heatmap(corr, cmap = 'Blues', annot = True, fmt = '.2f');

# %% [markdown]
# ### High correlation

# %%
# Get hightest correlation and exclude the diagnosis column
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(data2_df, 10))
# Out:
# Top Absolute Correlations
# radius_mean      perimeter_mean     0.997855
# radius_worst     perimeter_worst    0.993708
# radius_mean      area_mean          0.987357
# perimeter_mean   area_mean          0.986507
# radius_worst     area_worst         0.984015
# perimeter_worst  area_worst         0.977578
# radius_se        perimeter_se       0.972794
# perimeter_mean   perimeter_worst    0.970387
# radius_mean      radius_worst       0.969539
# perimeter_mean   radius_worst       0.969476
# dtype: float64

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Pass the axes into seaborn
axes[0,0].set_title('Radius Mean vs. Perimeter mean')
sns.scatterplot(data = data_df,
                x = 'radius_mean', 
                y = 'perimeter_mean', 
                hue = 'diagnosis', 
                ax = axes[0,0]);

axes[0,1].set_title('Radius Worst vs. Perimeter Worst')
sns.scatterplot(data = data_df,
                x = 'radius_worst', 
                y = 'perimeter_worst', 
                hue = 'diagnosis', 
                ax = axes[0,1]);

axes[1,0].set_title('Radius Mean vs. Area mean')
sns.scatterplot(data = data_df,
                x = 'radius_mean', 
                y = 'area_mean', 
                hue = 'diagnosis', 
                ax = axes[1,0]);

axes[1,1].set_title('Perimeter Mean vs. Area Mean')
sns.scatterplot(data = data_df,
                x = 'perimeter_mean', 
                y = 'area_mean', 
                hue = 'diagnosis', 
                ax = axes[1,1]);

plt.tight_layout(pad = 2);

# %% [markdown]
# High correlation between radius, perimeter and area as they are derived from each other.

# %% [markdown]
# ### Lowest correlation

# %%
# Get lowest correlation
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

print("Lowest Absolute Correlations")
print(get_top_abs_correlations(data2_df, 10))
# Out:
# Lowest Absolute Correlations
# fractal_dimension_mean  radius_se                  0.000111
# fractal_dimension_se    perimeter_worst            0.001000
#                         texture_worst              0.003195
# area_mean               fractal_dimension_worst    0.003738
# perimeter_mean          fractal_dimension_se       0.005523
# diagnosis               symmetry_se                0.006522
# texture_mean            smoothness_se              0.006614
# radius_mean             fractal_dimension_worst    0.007066
# diagnosis               texture_se                 0.008303
# texture_mean            symmetry_se                0.009127
# dtype: float64

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Pass the axes into seaborn
axes[0,0].set_title('Fractal Dimension Mean vs. Radius Standard Error')
sns.scatterplot(data = data_df,
                x = 'fractal_dimension_mean', 
                y = 'radius_se', 
                hue = 'diagnosis', 
                ax = axes[0,0]);

axes[0,1].set_title('Fractal Dimension SE vs. Perimeter Worst')
sns.scatterplot(data = data_df,
                x = 'fractal_dimension_se', 
                y = 'perimeter_worst', 
                hue = 'diagnosis', 
                ax = axes[0,1]);

axes[1,0].set_title('Fractal Dimension SE vs. Texture Worst')
sns.scatterplot(data = data_df,
                x = 'fractal_dimension_se', 
                y = 'texture_worst', 
                hue = 'diagnosis', 
                ax = axes[1,0]);

axes[1,1].set_title('Area Mean vs. Fractal Dimension Worst')
sns.scatterplot(data = data_df,
                x = 'area_mean', 
                y = 'fractal_dimension_worst', 
                hue = 'diagnosis', 
                ax = axes[1,1]);

plt.tight_layout(pad = 2);

# %% [markdown]
# ### Highest Inverse Correlation

# %%
# Get Highest Inverse correlation
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

print("Inverse Correlations")
print(get_top_abs_correlations(data2_df, 10))
# Out:
# Inverse Correlations
# radius_mean             fractal_dimension_mean   -0.311631
# area_mean               fractal_dimension_mean   -0.283110
# perimeter_mean          fractal_dimension_mean   -0.261477
# fractal_dimension_mean  radius_worst             -0.253691
#                         area_worst               -0.231854
# smoothness_se           radius_worst             -0.230691
# radius_mean             smoothness_se            -0.222600
# smoothness_se           perimeter_worst          -0.217304
# fractal_dimension_mean  perimeter_worst          -0.205151
# perimeter_mean          smoothness_se            -0.202694
# dtype: float64

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 9))

# Pass the axes into seaborn
axes[0,0].set_title('Radius Mean vs. Fractal Dimension Mean')
sns.scatterplot(data = data_df,
                x = 'radius_mean', 
                y = 'fractal_dimension_mean', 
                hue = 'diagnosis', 
                ax = axes[0,0]);

axes[0,1].set_title('Area Mean vs. Fractal Dimension Mean')
sns.scatterplot(data = data_df,
                x = 'area_mean', 
                y = 'fractal_dimension_mean', 
                hue = 'diagnosis', 
                ax = axes[0,1]);

axes[1,0].set_title('Perimeter Mean vs. Fractal Dimension Mean')
sns.scatterplot(data = data_df,
                x = 'perimeter_mean', 
                y = 'fractal_dimension_mean', 
                hue = 'diagnosis', 
                ax = axes[1,0]);

axes[1,1].set_title('Fractal Dimension Mean vs. Radius Worst')
sns.scatterplot(data = data_df,
                x = 'fractal_dimension_mean', 
                y = 'radius_worst', 
                hue = 'diagnosis', 
                ax = axes[1,1]);

plt.tight_layout(pad = 2);

# %% [markdown]
# ## Relation Between Tumours and Cell Nuclues
# Benign tumors are noncancerous. Malignant tumors are cancerous.

# %%
m_df = data_df[data_df.diagnosis == 'M']
b_df = data_df[data_df.diagnosis == 'B']

# %%
matplotlib.rcParams['figure.figsize'] = (16, 5)
plt.title('Radius Mean')
plt.hist(m_df.radius_mean, alpha=0.4, bins=np.arange(6.5, 29, 0.5));
plt.hist(b_df.radius_mean, alpha=0.4, bins=np.arange(6.5, 29, 0.5));
plt.legend(['M', 'B']);
